# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.1.0-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pydantic>=1.9 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (2.11.7)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (2.2.6)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (4.14.1)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.22.1-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.37.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (0.21.4)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached pypika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (1.74.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.17.4-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (3.11.2)
# Requirement already satisfied: httpx>=0.27.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (0.28.1)
# Collecting rich>=10.11.0 (from chromadb)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: requests<3.0,>=2.7 in d:\develops\generativeai\langchain\genai\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in d:\develops\generativeai\langchain\genai\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in d:\develops\generativeai\langchain\genai\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\develops\generativeai\langchain\genai\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\develops\generativeai\langchain\genai\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\develops\generativeai\langchain\genai\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\develops\generativeai\langchain\genai\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.8.3)
# Requirement already satisfied: packaging>=19.1 in d:\develops\generativeai\langchain\genai\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in d:\develops\generativeai\langchain\genai\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting tomli>=1.1.0 (from build>=1.0.3->chromadb)
#   Using cached tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio in d:\develops\generativeai\langchain\genai\lib\site-packages (from httpx>=0.27.0->chromadb) (4.10.0)
# Requirement already satisfied: httpcore==1.* in d:\develops\generativeai\langchain\genai\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\develops\generativeai\langchain\genai\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\develops\generativeai\langchain\genai\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\develops\generativeai\langchain\genai\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\develops\generativeai\langchain\genai\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\develops\generativeai\langchain\genai\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\develops\generativeai\langchain\genai\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\develops\generativeai\langchain\genai\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\develops\generativeai\langchain\genai\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in d:\develops\generativeai\langchain\genai\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in d:\develops\generativeai\langchain\genai\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in d:\develops\generativeai\langchain\genai\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in d:\develops\generativeai\langchain\genai\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.37.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.37.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.37.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.37.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.58b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\develops\generativeai\langchain\genai\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in d:\develops\generativeai\langchain\genai\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.34.4)
# Requirement already satisfied: filelock in d:\develops\generativeai\langchain\genai\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.7.0)
# Requirement already satisfied: click>=8.0.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.4-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in d:\develops\generativeai\langchain\genai\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-15.0.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\develops\generativeai\langchain\genai\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\develops\generativeai\langchain\genai\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\develops\generativeai\langchain\genai\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.1.0-cp39-abi3-win_amd64.whl (19.8 MB)
#    ---------------------------------------- 0.0/19.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.8 MB ? eta -:--:--
#    - -------------------------------------- 0.8/19.8 MB 2.8 MB/s eta 0:00:07
#    --- ------------------------------------ 1.6/19.8 MB 3.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.6/19.8 MB 3.8 MB/s eta 0:00:05
#    ------- -------------------------------- 3.7/19.8 MB 4.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 5.0/19.8 MB 4.4 MB/s eta 0:00:04
#    ------------ --------------------------- 6.3/19.8 MB 4.6 MB/s eta 0:00:03
#    -------------- ------------------------- 7.3/19.8 MB 4.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 8.4/19.8 MB 4.9 MB/s eta 0:00:03
#    ------------------- -------------------- 9.7/19.8 MB 5.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 11.0/19.8 MB 5.1 MB/s eta 0:00:02
#    ------------------------ --------------- 12.3/19.8 MB 5.2 MB/s eta 0:00:02
#    --------------------------- ------------ 13.6/19.8 MB 5.2 MB/s eta 0:00:02
#    ------------------------------ --------- 14.9/19.8 MB 5.3 MB/s eta 0:00:01
#    -------------------------------- ------- 16.3/19.8 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.6/19.8 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 18.9/19.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  19.7/19.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 19.8/19.8 MB 5.4 MB/s eta 0:00:00
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    --------------------------- ------------ 1.3/1.9 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 6.3 MB/s eta 0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.0-cp310-cp310-win_amd64.whl (41 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading onnxruntime-1.22.1-cp310-cp310-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.7 MB 6.1 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.7 MB 6.3 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.7 MB 6.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.7 MB 6.2 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/12.7 MB 6.2 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/12.7 MB 6.3 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.7 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 6.3 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.37.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.37.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.37.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.37.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl (131 kB)
# Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl (207 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.4.2-cp310-cp310-win_amd64.whl (35 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached tomli-2.2.1-py3-none-any.whl (14 kB)
# Downloading typer-0.17.4-py3-none-any.whl (46 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Using cached httptools-0.6.4-cp310-cp310-win_amd64.whl (88 kB)
# Downloading watchfiles-1.1.0-cp310-cp310-win_amd64.whl (292 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, websockets, websocket-client, tomli, shellingham, pyreadline3, pyproject_hooks, pybase64, overrides, opentelemetry-proto, oauthlib, mmh3, mdurl, importlib-resources, httptools, bcrypt, backoff, uvicorn, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, markdown-it-py, humanfriendly, build, watchfiles, rich, opentelemetry-semantic-conventions, kubernetes, coloredlogs, typer, opentelemetry-sdk, onnxruntime, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    ----------------------------------------  0/37 [pypika]
#    - --------------------------------------  1/37 [flatbuffers]
#    --- ------------------------------------  3/37 [websockets]
#    --- ------------------------------------  3/37 [websockets]
#    --- ------------------------------------  3/37 [websockets]
#    --- ------------------------------------  3/37 [websockets]
#    ---- -----------------------------------  4/37 [websocket-client]
#    ---- -----------------------------------  4/37 [websocket-client]
#    ---- -----------------------------------  4/37 [websocket-client]
#    ------ ---------------------------------  6/37 [shellingham]
#    ------- --------------------------------  7/37 [pyreadline3]
#    ------- --------------------------------  7/37 [pyreadline3]
#    ------- --------------------------------  7/37 [pyreadline3]
#    --------- ------------------------------  9/37 [pybase64]
#    ---------- ----------------------------- 10/37 [overrides]
#    ----------- ---------------------------- 11/37 [opentelemetry-proto]
#    ----------- ---------------------------- 11/37 [opentelemetry-proto]
#    ------------ --------------------------- 12/37 [oauthlib]
#    ------------ --------------------------- 12/37 [oauthlib]
#    ------------ --------------------------- 12/37 [oauthlib]
#    ------------ --------------------------- 12/37 [oauthlib]
#    ------------ --------------------------- 12/37 [oauthlib]
#    ------------ --------------------------- 12/37 [oauthlib]
#    --------------- ------------------------ 14/37 [mdurl]
#    ---------------- ----------------------- 15/37 [importlib-resources]
#    ---------------- ----------------------- 15/37 [importlib-resources]
#    ------------------- -------------------- 18/37 [backoff]
#    -------------------- ------------------- 19/37 [uvicorn]
#    -------------------- ------------------- 19/37 [uvicorn]
#    -------------------- ------------------- 19/37 [uvicorn]
#    --------------------- ------------------ 20/37 [requests-oauthlib]
#    ---------------------- ----------------- 21/37 [posthog]
#    ---------------------- ----------------- 21/37 [posthog]
#    ---------------------- ----------------- 21/37 [posthog]
#    ---------------------- ----------------- 21/37 [posthog]
#    ---------------- ---------- 22/37 [opentelemetry-exporter-otlp-proto-common]
#    ------------------------ --------------- 23/37 [opentelemetry-api]
#    ------------------------ --------------- 23/37 [opentelemetry-api]
#    ------------------------ --------------- 23/37 [opentelemetry-api]
#    ------------------------- -------------- 24/37 [markdown-it-py]
#    ------------------------- -------------- 24/37 [markdown-it-py]
#    ------------------------- -------------- 24/37 [markdown-it-py]
#    ------------------------- -------------- 24/37 [markdown-it-py]
#    ------------------------- -------------- 24/37 [markdown-it-py]
#    --------------------------- ------------ 25/37 [humanfriendly]
#    --------------------------- ------------ 25/37 [humanfriendly]
#    ---------------------------- ----------- 26/37 [build]
#    ---------------------------- ----------- 26/37 [build]
#    ----------------------------- ---------- 27/37 [watchfiles]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    ------------------------- ------- 29/37 [opentelemetry-semantic-conventions]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    -------------------------------- ------- 30/37 [kubernetes]
#    --------------------------------- ------ 31/37 [coloredlogs]
#    ---------------------------------- ----- 32/37 [typer]
#    ---------------------------------- ----- 32/37 [typer]
#    ----------------------------------- ---- 33/37 [opentelemetry-sdk]
#    ----------------------------------- ---- 33/37 [opentelemetry-sdk]
#    ----------------------------------- ---- 33/37 [opentelemetry-sdk]
#    ----------------------------------- ---- 33/37 [opentelemetry-sdk]
#    ----------------------------------- ---- 33/37 [opentelemetry-sdk]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    ------------------------------------ --- 34/37 [onnxruntime]
#    --------------------------- - 35/37 [opentelemetry-exporter-otlp-proto-grpc]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    -------------------------------------- - 36/37 [chromadb]
#    ---------------------------------------- 37/37 [chromadb]
#
# Successfully installed backoff-2.2.1 bcrypt-4.3.0 build-1.3.0 chromadb-1.1.0 coloredlogs-15.0.1 durationpy-0.10 flatbuffers-25.2.10 httptools-0.6.4 humanfriendly-10.0 importlib-resources-6.5.2 kubernetes-33.1.0 markdown-it-py-4.0.0 mdurl-0.1.2 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.22.1 opentelemetry-api-1.37.0 opentelemetry-exporter-otlp-proto-common-1.37.0 opentelemetry-exporter-otlp-proto-grpc-1.37.0 opentelemetry-proto-1.37.0 opentelemetry-sdk-1.37.0 opentelemetry-semantic-conventions-0.58b0 overrides-7.7.0 posthog-5.4.0 pybase64-1.4.2 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rich-14.1.0 shellingham-1.5.4 tomli-2.2.1 typer-0.17.4 uvicorn-0.35.0 watchfiles-1.1.0 websocket-client-1.8.0 websockets-15.0.1

# %%
from langchain_community.document_loaders import TextLoader
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline
from langchain_huggingface import HuggingFaceEmbeddings
import os
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

os.environ["HF_HOME"] = 'D:/huggingface_cache'
os.environ["TRANSFORMERS_CACHE"] = "D:/huggingface_cache/transformers"

llm = HuggingFacePipeline.from_model_id(
    model_id= "TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
    # pipeline_kwargs=dict(
    #     temperature = 0.5,
    #     max_new_tokens = 100
    # )
)
#initialize the LLM
model = HuggingFaceEmbeddings(llm = llm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       8 os.environ["HF_HOME"] = 'D:/huggingface_cache'
#       9 os.environ["TRANSFORMERS_CACHE"] = "D:/huggingface_cache/transformers"
# ---> 11 llm = HuggingFacePipeline.from_model_id(
#      12     model_id= "TinyLlama/TinyLlama-1.1B-Chat-v1.0",
#      13     # task="text-generation",
#      14     # pipeline_kwargs=dict(
#      15     #     temperature = 0.5,
#      16     #     max_new_tokens = 100
#      17     # )
#      18 )
#      19 #initialize the LLM
#      20 model = HuggingFaceEmbeddings(llm = llm)
#
# TypeError: HuggingFacePipeline.from_model_id() missing 1 required positional argument: 'task'

# %%
from langchain.vectorstores import Chroma

# %%
from langchain.schema import Document

#create Langchain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=OpenAIEmbeddings(),
    persist_directory='my_chroma_db',
    collection_name='sample'
)

# %%
# add documents
vector_store.add_documents(docs)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
)

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)

# %%
# update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='09a39dc6-3ba6-4ea7-927e-fdda591da5e4', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])

# %%
# delete document
vector_store.delete(ids=['09a39dc6-3ba6-4ea7-927e-fdda591da5e4'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
